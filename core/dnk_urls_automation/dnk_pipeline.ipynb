# %% [markdown]
# ### 1) DNK-URLS finden und in der TXT-Datei
# `data/url_sources/dnk_2024_individually.txt`

# %%
import sys, os
from core.dnk_urls_automation.scrape_dnk_urls import scrape_dnk_urls

# Projektordner automatisch ermitteln (2 Ebenen über dem Notebook)
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
sys.path.append(PROJECT_ROOT)


"""
Argumente:
    1. Start_ID (ab hier beginnen)
    2. End_ID (bis hier suchen)
    3. Year (für welches Jahr möchtest du suchen)
"""
scrape_dnk_urls(12000, 19000, 2024) # nach meiner Analyse, die Grenzen liegen zwischen 12.000 und 19.000

# %% [markdown]
# ### 2) Die gefundene URLs automatisch extrahieren
# `data/url_sources/dnk_2024_individually.txt` → `data/url_sources/dnk_2024_all.txt`
#
# ### 3) Dann alle Inhalte aus der URLs `dnk_{year}_all.txt` in `upload`-Ordner als MD-Format bereinigt speichern

# %%
import sys, os
from core.dnk_urls_automation.extract_dnk_urls import extract_dnk_urls
from core.dnk_urls_automation.dnk_urls_2_md import dnk_urls_2_md

# Projektordner automatisch ermitteln (2 Ebenen über dem Notebook)
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
sys.path.append(PROJECT_ROOT)

"""
Argumente:
    Year (für welches Jahr möchtest du die URLs extrahieren)
"""
extract_dnk_urls(2024) # 2) extrahieren
dnk_urls_2_md(2024)    # 3) als md speichern
